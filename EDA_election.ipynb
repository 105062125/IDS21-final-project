# %%
import pandas as pd
import matplotlib.pyplot as plt
import os

# %%
election_data_dir = r'C:\Users\lynne\Documents\Fall_2021\05839 Interactive Data Science\Homework 4\data\election'

# %%
facebook_after_election = pd.read_csv(os.path.join(election_data_dir, 'facebook_after_election.csv'))
facebook_before_election = pd.read_csv(os.path.join(election_data_dir, 'facebook_before_election.csv'))

facebook_after_election['created_at'] = pd.to_datetime(facebook_after_election['created_at'])
facebook_before_election['created_at'] = pd.to_datetime(facebook_before_election['created_at'])

# %%
plt.plot(facebook_after_election['created_at'], facebook_after_election['emotion.joy'])
plt.show()
